# %%
# !pip install git+https://github.com/remykarem/python2jupyter#egg=p2j
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting p2j
#   Cloning https://github.com/remykarem/python2jupyter to /tmp/pip-install-zszzymee/p2j_fba6276660e24dc0ad3ee3959d896556
#   Running command git clone --filter=blob:none --quiet https://github.com/remykarem/python2jupyter /tmp/pip-install-zszzymee/p2j_fba6276660e24dc0ad3ee3959d896556
#   Resolved https://github.com/remykarem/python2jupyter to commit 065420bee214fc2d0ef0c69c0714521f3c6a3428
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: p2j
#   Building wheel for p2j (setup.py) ... done
#   Created wheel for p2j: filename=p2j-1.3.3-py3-none-any.whl size=10090 sha256=6dd659c61e3fd85fabfcba85a7699953b87d88503e1cf0c4d13d794ec12fdcf6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-p0tnmll2/wheels/f5/8a/25/d5d5aa9bdbe19c06cb95e6c8c93893863fdbec1e196ca238c4
# Successfully built p2j
# Installing collected packages: p2j
# Successfully installed p2j-1.3.3

# %%
# !p2j /content/drive/MyDrive/ColabNotebooks/userBased.py
# Out:
# Notebook /content/drive/MyDrive/ColabNotebooks/userBased.ipynb written.
